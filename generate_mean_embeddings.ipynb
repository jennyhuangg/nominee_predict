# %% [markdown]
# # Generate Mean Embeddings for Confirmation Hearing Text
# This python notebook generates the mean text embeddings over all the words in the confirmation hearings of each jusice. It outputs these mean text embeddings (with dimension 300) as an array, where each row corresponds to a justice.

# %%
# http://yaronvazana.com/2018/09/20/average-word-vectors-generate-document-paragraph-sentence-embeddings/
import os
import string
import pickle
import numpy as np
import pandas as pd

import gensim
import nltk
from nltk import word_tokenize
from nltk import download
from nltk.corpus import stopwords
from gensim.models import word2vec
import multiprocessing

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
get_ipython().magic('matplotlib inline')
# Out:
# [nltk_data] Downloading package punkt to /Users/jhuang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jhuang/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Get file names
in_dir = "nlp_approach/data/transcripts/utterances"
files = os.listdir(in_dir)
files.sort()
new_files = []
justicenames = []
for f in files:
    if f.endswith(".txt"):
        new_files.append(os.path.join(in_dir,f))
        justicenames.append(f[:-4])

print(justicenames)
# Out:
# ['AJGoldberg', 'AMKennedy', 'AScalia', 'BRWhite', 'DHSouter', 'EKagan', 'JGRoberts', 'JPStevens', 'LFPowell', 'NMGorsuch', 'RBGinsburg', 'SAAlito', 'SDOConnor', 'SGBreyer', 'SSotomayor', 'TMarshall', 'WHRehnquist']

# %% [markdown]
# ## Load pre-trained word embedding model.

# %%
# Load Google's pre-trained Word2Vec model.
w = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)
# Out:
# 2019-05-10 22:06:14,164 : INFO : loading projection weights from GoogleNews-vectors-negative300.bin.gz
# 2019-05-10 22:06:14,166 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-05-10 22:09:21,423 : INFO : loaded (3000000, 300) matrix from GoogleNews-vectors-negative300.bin.gz

# %%
w.save("pretrained_word2vec_model")
# Out:
# 2019-05-10 22:10:53,272 : INFO : saving Word2VecKeyedVectors object under pretrained_word2vec_model, separately None
# 2019-05-10 22:10:53,273 : INFO : storing np array 'vectors' to pretrained_word2vec_model.vectors.npy
# 2019-05-10 22:11:33,382 : INFO : not storing attribute vectors_norm
# 2019-05-10 22:11:33,421 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-05-10 22:12:00,895 : INFO : saved pretrained_word2vec_model

# %% [markdown]
# ## Process documents.

# %%
# source: https://github.com/sdimi/average-word2vec/blob/master/avg_word2vec_from_documents.py
def preprocess(text):
    text = text.lower()
    doc = word_tokenize(text)
    doc = [word for word in doc if word not in stop_words]
    doc = [word for word in doc if word.isalpha()] #restricts string to alphabetic characters only
    return doc

def get_corpus(files):
    corpus = []
    for f in files:
        with open(f, 'r') as file:
            data = file.read().replace('\n', '')
        data = preprocess(data)
        corpus.append(data)
    return corpus

# %%
corpus = get_corpus(new_files)
print(corpus[0])
# Out:
# ['chairman', 'would', 'like', 'make', 'one', 'two', 'corrections', 'biography', 'chamman', 'right', 'received', 'college', 'education', 'junior', 'city', 'chicago', 'public', 'institution', 'calledcrane', 'junior', 'college', 'city', 'college', 'city', 'attended', 'college', 'also', 'moonlighted', 'addition', 'attendance', 'juniorcollege', 'took', 'additional', 'course', 'could', 'get', 'law', 'school', 'withthe', 'proper', 'credits', 'depaul', 'university', 'university', 'located', 'degrees', 'northwestern', 'university', 'law', 'school', 'bachelor', 'science', 'law', 'instead', 'received', 'jurisdoctor', 'inducted', 'army', 'inducted', 'major', 'inducted', 'captain', 'promoted', 'rank', 'army', 'career', 'listed', 'captain', 'army', 'promoted', 'major', 'never', 'promoted', 'colonel', 'iwas', 'put', 'reserves', 'much', 'later', 'recently', 'corrected', 'biographical', 'sketch', 'goldberg', 'follows', 'arthur', 'goldbergborn', 'august', 'chicago', 'crane', 'junior', 'college', 'depaul', 'university', 'northwestern', 'university', 'law', 'school', 'chicago', 'bar', 'district', 'private', 'practice', 'law', 'chicago', 'john', 'marshall', 'law', 'school', 'chicago', 'office', 'strategic', 'services', 'army', 'captain', 'major', 'instructor', 'goldberg', 'devoe', 'shadur', 'mikva', 'chicago', 'goldberg', 'feller', 'bredhoff', 'washington', 'law', 'partner', 'general', 'counsel', 'special', 'counsel', 'united', 'steel', 'workers', 'america', 'general', 'counsel', 'secretary', 'labor', 'united', 'status', 'married', 'two', 'children', 'office', 'department', 'labor', 'washington', 'home', 'albemarle', 'street', 'washington', 'associate', 'justice', 'supreme', 'court', 'united', 'since', 'began', 'practice', 'nomination', 'arthur', 'goldbergchairman', 'want', 'take', 'time', 'probably', 'ca', 'thiiu', 'cuff', 'mr', 'goldberg', 'since', 'began', 'practice', 'law', 'chicago', 'joined', 'became', 'member', 'chicago', 'bar', 'association', 'illinois', 'bar', 'association', 'american', 'bar', 'association', 'member', 'national', 'lawyers', 'guild', 'member', 'many', 'organizations', 'identified', 'jewish', 'faith', 'american', 'jewish', 'congress', 'identified', 'american', 'jdewi', 'ihshavce', 'opmrombiattbeley', 'belonged', 'groups', 'names', 'ido', 'recall', 'glad', 'furnish', 'would', 'delighted', 'mir', 'chairman', 'would', 'like', 'file', 'list', 'chaimrwn', 'want', 'goldberg', 'member', 'american', 'civil', 'liberties', 'union', 'chicago', 'member', 'independent', 'voters', 'principal', 'member', 'democratic', 'party', 'many', 'years', 'think', 'capacity', 'member', 'committees', 'president', 'probabl', 'exaggeration', 'many', 'committees', 'president', 'shall', 'glad', 'file', 'complete', 'list', 'ciiairman', 'senator', 'kefauver', 'difficult', 'task', 'person', 'like', 'led', 'active', 'life', 'expressed', 'many', 'subjects', 'deep', 'feelings', 'subjects', 'still', 'different', 'person', 'person', 'prior', 'appearances', 'approved', 'senate', 'take', 'office', 'justice', 'would', 'regard', 'first', 'task', 'primary', 'task', 'justice', 'supreme', 'court', 'guard', 'justice', 'brandeis', 'said', 'lest', 'prejudices', 'convictions', 'predilections', 'erected', 'legal', 'obligation', 'confirmed', 'confirmed', 'enforce', 'congress', 'right', 'way', 'president', 'way', 'right', 'enforce', 'apply', 'constitution', 'united', 'states', 'different', 'obligation', 'much', 'serious', 'obligation', 'one', 'private', 'citizen', 'expresses', 'many', 'difficult', 'thing', 'human', 'beings', 'product', 'environment', 'experience', 'know', 'higher', 'obligation', 'judge', 'guard', 'predilections', 'try', 'decide', 'cases', 'basis', 'law', 'arthur', 'goldbergunder', 'constitution', 'united', 'states', 'separation', 'powers', 'article', 'section', 'constitution', 'legislative', 'powers', 'vested', 'congress', 'hope', 'intend', 'justice', 'respect', 'secret', 'great', 'democracy', 'executive', 'power', 'article', 'vested', 'president', 'article',  ...

# %% [markdown]
# ## Get mean embeddings.

# %%
# source: http://yaronvazana.com/2018/09/20/average-word-vectors-generate-document-paragraph-sentence-embeddings/
def get_mean_vector(word2vec_model, words):
    # remove out-of-vocabulary words
    words = [word for word in words if word in word2vec_model.vocab]
    if len(words) >= 1:
        return np.mean(word2vec_model[words], axis=0)
    else:
        return []

# %%
vectors = []
for doc in corpus:
    vec = get_mean_vector(w, doc)
    vectors.append(vec)
print(len(vectors))
np.save("mean_embeddings.npy", vectors)
# Out:
# 17
